# %%
import matplotlib.pyplot as plt
import requests
from requests.packages.urllib3.util.retry import Retry
import json
import datetime
import pandas as pd
from math import isnan
import concurrent.futures
import logging
import gc
from pprint import pprint

# %%
username = 'OOIAPI-30AZZ33CYL06XZ'
token = 'M8OD8XIG5KD'
array = 'cabled'

QC_PARAMETER_URL = 'https://ooinet.oceanobservatories.org/api/m2m/12578/qcparameters/'
DEPLOYEMENT_URL = 'https://ooinet.oceanobservatories.org/api/m2m/12587/events/deployment/inv/'
DATA_URL = 'https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/'

# %%
print("requesting qc data...")
r = requests.get(QC_PARAMETER_URL, auth=(username, token))
data = r.json()

refdes_qc_list = []
parameter_qc_list = []
globalrange_min_qc_list = []

for i in range(len(data)):
    if data[i]['qcParameterPK']['qcId'] == 'dataqc_globalrangetest_minmax' \
    and data[i]['qcParameterPK']['parameter'] == 'dat_min':
        
        refdes = data[i]['qcParameterPK']['refDes']['subsite']+'-'+\
            data[i]['qcParameterPK']['refDes']['node']+'-'+\
            data[i]['qcParameterPK']['refDes']['sensor']
        refdes_qc_list.append(refdes)
        
        parameter = data[i]['qcParameterPK']['streamParameter']
        parameter_qc_list.append(parameter)
        
        globalrange_min = data[i]['value']
        globalrange_min_qc_list.append(globalrange_min)

qc_dict = {
    'refdes':refdes_qc_list,
    'parameter':parameter_qc_list,
    'global_range_min':globalrange_min_qc_list,
}     
        
globalrange_min_qc_data = pd.DataFrame(qc_dict,columns=['refdes','parameter','global_range_min'])

refdes_qc_list = []
parameter_qc_list = []
globalrange_max_qc_list = []

for i in range(len(data)):
    if data[i]['qcParameterPK']['qcId'] == 'dataqc_globalrangetest_minmax' \
    and data[i]['qcParameterPK']['parameter'] == 'dat_max':
        
        refdes = data[i]['qcParameterPK']['refDes']['subsite']+'-'+\
            data[i]['qcParameterPK']['refDes']['node']+'-'+\
            data[i]['qcParameterPK']['refDes']['sensor']
        refdes_qc_list.append(refdes)
        
        parameter = data[i]['qcParameterPK']['streamParameter']
        parameter_qc_list.append(parameter)
        
        globalrange_max = data[i]['value']
        globalrange_max_qc_list.append(globalrange_max)

qc_dict = {
    'refdes':refdes_qc_list,
    'parameter':parameter_qc_list,
    'global_range_max':globalrange_max_qc_list,
}     
        
globalrange_max_qc_data = pd.DataFrame(qc_dict,columns=['refdes','parameter','global_range_max'])

global_ranges = pd.merge(globalrange_min_qc_data,globalrange_max_qc_data, on=['refdes','parameter'], how='outer')
# Out:
# requesting qc data...

# %%
# set up some functions
def request_data(url,username,token):
    auth = (username, token)
    return session.get(url,auth=auth)

def to_integer(dt_time):
    return 10000*dt_time.year + 100*dt_time.month + dt_time.day

def diff_days(d1,d2):
    return (d2 - d1).days

ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()

pool = concurrent.futures.ThreadPoolExecutor(max_workers=20)
session = requests.session()
retry = Retry(
        total=10,
        backoff_factor=0.3,
    )
adapter = requests.adapters.HTTPAdapter(pool_connections=100, pool_maxsize=100,max_retries=retry,pool_block=True)
session.mount('http://', adapter)

logging.basicConfig(filename=array+'_requests.log',level=logging.DEBUG)

refdes = 'input/' + array + '.csv'
refdes_list = pd.read_csv(refdes)
refdes_list = refdes_list['refdes']
refdes_list = refdes_list.drop_duplicates()

print('\n'+"working on", array)
print("building deployment info requests...")
asset_requests = []
for i in refdes_list:
    sub_site = i[:8]
    platform = i[9:14]
    instrument = i[15:27]
    asset_url_inputs = '/'.join((sub_site, platform, instrument))
    request_url = DEPLOYEMENT_URL+asset_url_inputs+'/-1'
    asset_requests.append(request_url)

print("sending deployment info requests...")
ref_des_list = []
start_time_list = []
end_time_list = []
deployment_list = []

future_to_url = {pool.submit(request_data, url, username, token): url for url in asset_requests}
for future in concurrent.futures.as_completed(future_to_url):
    try:
        asset_info = future.result()
        asset_info = asset_info.json()

        for i in range(len(asset_info)):
            refdes = asset_info[i]['referenceDesignator']
            ref_des_list.append(refdes)

            deployment = asset_info[i]['deploymentNumber']
            deployment_list.append(deployment)

            start = asset_info[i]['eventStartTime']
            end = asset_info[i]['eventStopTime']

            try:
                start_time = datetime.datetime.utcfromtimestamp(start/1000.0)
                start_time_list.append(start_time)

                end_time = datetime.datetime.utcfromtimestamp(end/1000.0)
                end_time_list.append(end_time)

            except:
                end_time = datetime.datetime.utcnow()
                end_time_list.append(end_time)

    except:
        pass

data_dict = {
    'refdes':ref_des_list,
    'deployment':deployment_list,
    'start_time':start_time_list,
    'end_time':end_time_list}
deployment_data = pd.DataFrame(data_dict, columns = ['refdes', 'deployment','start_time', 'end_time'])
# Out:
# working on cabled
# building deployment info requests...
# sending deployment info requests...

# %%
print("calculating days between deployment dates...")
deployment_data_days = pd.DataFrame(columns = ['refdes', 'deployment','date'])

# calculate days between deployment dates
for index, row in deployment_data.iterrows():
    start_time = row['start_time']
    end_time = row['end_time']
    periods = diff_days(start_time, end_time)
    start_time = to_integer(start_time)
    total_days = pd.DataFrame({'date' : pd.date_range(str(start_time),periods=periods,freq='D')})

    total_days['refdes'] = row['refdes']
    total_days['deployment'] = row['deployment']
    deployment_data_days = deployment_data_days.append(total_days)

# re-order data frame columns
deployment_data_days = deployment_data_days[['refdes', 'deployment','date']]

print("building data request urls...")
deployment_data_days['start_date'] = deployment_data_days['date'] + datetime.timedelta(seconds=5)
deployment_data_days['end_date'] = deployment_data_days['date'] + datetime.timedelta(seconds=86395)

qc_db_input = 'input/' + array + '.csv'
qc_db_input = pd.read_csv(qc_db_input)
refdes_streams_df = qc_db_input[['refdes','method','stream','parameter']]
refdes_streams_df = refdes_streams_df.drop_duplicates()

request_inputs = pd.merge(refdes_streams_df,deployment_data_days, on='refdes')

request_inputs['subsite'] = request_inputs.refdes.str[:8]
request_inputs['platform'] = request_inputs.refdes.str[9:14]
request_inputs['instrument'] = request_inputs.refdes.str[15:27]
request_inputs['start_date'] = pd.to_datetime(request_inputs['start_date'])
request_inputs['start_date'] = request_inputs.start_date.dt.strftime('%Y-%m-%dT%H:%M:%S.000Z')
request_inputs['end_date'] = pd.to_datetime(request_inputs['end_date'])
request_inputs['end_date'] = request_inputs.end_date.dt.strftime('%Y-%m-%dT%H:%M:%S.000Z')

request_inputs['urls'] = DATA_URL+\
                        request_inputs.subsite+\
                        '/'+request_inputs.platform+\
                        '/'+request_inputs.instrument+\
                        '/'+request_inputs.method+\
                        '/'+request_inputs.stream+\
                        '?beginDT='+request_inputs.start_date+\
                        '&endDT='+request_inputs.end_date+\
                        '&limit=50'

request_urls = request_inputs['urls'].drop_duplicates()
request_urls = request_urls.tolist()
# Out:
# calculating days between deployment dates...
# building data request urls...

# %%
print("sending data requests for", array+'...')
print('\t',"current time:", datetime.datetime.now())
print('\t',len(request_urls ),"data requests being sent")
print('\t',"check",array+"_requests.log","file in your working directory for progress")

finaldf = pd.DataFrame()
missing = []

future_to_url = {pool.submit(request_data, url, username, token): url for url in request_urls}
for future in concurrent.futures.as_completed(future_to_url):
#     url = future_to_url[future]
    try:
        data = future.result() 
        data = data.json()

        refdes_list = []
        parameter_list = []
        timestamp_list = []
        value_list = []
        
        # use this to speed up the loop
#         df = pd.DataFrame.from_records(map(json.loads, map(json.dumps,data)))
        
        # iterate through data points to extract time stamps
        for i in range(len(data)):
            timestamp = data[i]['time']
            timestamp = datetime.datetime.utcfromtimestamp(timestamp - ntp_delta).replace(microsecond=0)
            timestamp = timestamp.date()
      
            # get refdes from the response and create data frame y with the corresponding gloabl range values
            refdes = data[i]['pk']['subsite'] + '-' + data[i]['pk']['node'] + '-' + data[i]['pk']['sensor']
            x = global_ranges['refdes'] == refdes
            y = global_ranges[x]

            # check if global range list contains an entry for the refdes
            templist = list(global_ranges['refdes'])
            if refdes not in templist:
                missing.append(refdes)
                
                
            # iterate through all variables in global range data frame y, then iterate through keys in data point
            # to find matching keys, then grab values
            for var in y.parameter.values:
                for j in data[i].keys():
                    if var == j:
                        z = data[i][j]
                        
                        # conditional to handle 2d datasets, in which case the first non nan value is checked
                        if type(z) != list:
                            refdes_list.append(refdes)
                            parameter_list.append(var)
                            value_list.append(z)
                            timestamp_list.append(timestamp)
                        else:
                            u = next(u for u in z if not isnan(u))
                            refdes_list.append(refdes)
                            parameter_list.append(var)
                            value_list.append(u)
                            timestamp_list.append(timestamp)
                            

        # create data frame from lists collected above
        data_dict = {
            'refdes':refdes_list,
            'parameter':parameter_list,
            'value':value_list,
            'date':timestamp_list}
        response_data = pd.DataFrame(data_dict, columns = ['refdes','parameter','value','date'])

        # merge into data frame with global range values and check if value between global ranges
        df = y.merge(response_data,how='outer')
        df['pass'] = (df['value'] < pd.to_numeric(df['global_range_max'])) & \
                        (df['value'] > pd.to_numeric(df['global_range_min']))

        # collapse the data frame to calculate percent of data points that pass the test for that day
        df2 = df['pass'].groupby([df['refdes'], \
                    df['parameter'],\
                  df['date'] \
                   ]).sum().reset_index()
        df2['percent'] = (df2['pass'] / len(data)) * 100
        df2['data_points'] = len(data)
        df2 = df2[['refdes','parameter','date','data_points','percent']]

        # append result for this ref des and day to final data frame
        finaldf = finaldf.append(df2)
            
    except:
#         print('no data for ', url)
        pass

#     gc.collect()
# Out:
# sending data requests for cabled...
# 	 current time: 2017-11-29 00:14:30.287136
# 	 66579 data requests being sent
# 	 check cabled_requests.log file in your working directory for progress

# %%
finaldf.to_csv('output/'+array+'_quality.csv', index=False)

# get list of instruments and parameters for which no data was returned, or no qc values are available
returns = finaldf[['refdes','parameter']].drop_duplicates()
expected = qc_db_input[['refdes','parameter']].drop_duplicates()
not_found = returns.merge(expected,indicator=True, how='outer')
not_found = not_found[not_found['_merge'] == 'right_only']
del not_found['_merge']
print(not_found,'\n')

# get list of just instruments missing qc values all together
print('the following reference designators are missing global range values\n',set(missing))
# Out:
#                           refdes  \
# 145  RS01SBPD-DP01A-03-FLCDRA102
# 146  RS01SBPD-DP01A-04-FLNTUA102
# 147  RS01SBPD-DP01A-04-FLNTUA102
# 148  RS01SBPD-DP01A-04-FLNTUA102
# 149  RS01SBPD-DP01A-05-OPTAAC102
# 150  RS01SBPD-DP01A-05-OPTAAC102
# 151  RS01SBPS-PC01A-06-VADCPA101
# 152  RS01SBPS-PC01A-07-CAMDSC102
# 153  RS01SBPS-PC01A-4A-DOSTAD103
# 154  RS01SBPS-PC01A-4A-DOSTAD103
# 155  RS01SBPS-PC01A-4A-DOSTAD103
# 156  RS01SBPS-PC01A-4A-DOSTAD103
# 157  RS01SBPS-PC01A-4A-DOSTAD103
# 158  RS01SBPS-PC01A-4A-DOSTAD103
# 159  RS01SBPS-PC01A-4A-DOSTAD103
# 160  RS01SBPS-PC01A-4B-PHSENA102
# 161  RS01SBPS-PC01A-4C-FLORDD103
# 162  RS01SBPS-SF01A-2A-DOFSTA102
# 163  RS01SBPS-SF01A-2A-DOFSTA102
# 164  RS01SBPS-SF01A-2A-DOFSTA102
# 165  RS01SBPS-SF01A-2A-DOFSTA102
# 166  RS01SBPS-SF01A-2A-DOFSTA102
# 167  RS01SBPS-SF01A-2A-DOFSTA102
# 168  RS01SBPS-SF01A-2D-PHSENA101
# 169  RS01SBPS-SF01A-3A-FLORTD101
# 170  RS01SBPS-SF01A-3D-SPKIRA101
# 171  RS01SBPS-SF01A-4A-NUTNRA101
# 172  RS01SBPS-SF01A-4A-NUTNRA101
# 173  RS01SBPS-SF01A-4B-VELPTD102
# 174  RS01SBPS-SF01A-4B-VELPTD102
# ..                           ...
# 341  RS03INT1-MJ03C-07-RASFLA301
# 342  RS03INT1-MJ03C-07-RASFLA301
# 343  RS03INT1-MJ03C-09-THSPHA301
# 344  RS03INT1-MJ03C-09-THSPHA301
# 345  RS03INT1-MJ03C-09-THSPHA301
# 346  RS03INT1-MJ03C-09-THSPHA301
# 347  RS03INT1-MJ03C-09-THSPHA301
# 348  RS03INT1-MJ03C-09-THSPHA301
# 349  RS03INT1-MJ03C-09-THSPHA301
# 350  RS03INT1-MJ03C-09-THSPHA301
# 351  RS03INT1-MJ03C-10-TRHPHA301
# 352  RS03INT1-MJ03C-10-TRHPHA301
# 353  RS03INT1-MJ03C-10-TRHPHA301
# 354  RS03INT1-MJ03C-10-TRHPHA301
# 355  RS03INT2-MJ03D-05-OBSSPA305
# 356  RS03INT2-MJ03D-06-BOTPTA303
# 357  RS03INT2-MJ03D-06-BOTPTA303
# 358  RS03INT2-MJ03D-06-BOTPTA303
# 359  RS03INT2-MJ03D-06-BOTPTA303
# 360  RS03INT2-MJ03D-06-BOTPTA303
# 361  RS03INT2-MJ03D-06-BOTPTA303
# 362  RS03INT2-MJ03D-06-BOTPTA303
# 363  RS03INT2-MJ03D-06-BOTPTA303
# 364  RS03INT2-MJ03D-06-BOTPTA303
# 365  RS03INT2-MJ03D-06-BOTPTA303
# 366  RS03INT2-MJ03D-06-BOTPTA303
# 367  RS03INT2-MJ03D-06-BOTPTA303
# 368  RS03INT2-MJ03D-12-VEL3DB304
# 369  RS03INT2-MJ03D-12-VEL3DB304
# 370  RS03INT2-MJ03D-12-VEL3DB304
#
#                                              parameter
# 145                  flcdr_x_mmp_cds_fluorometric_cdom
# 146  flntu_x_mmp_cds_total_volume_scattering_coeffi...
# 147         flntu_x_mmp_cds_fluorometric_chlorophyll_a
# 148                        flntu_x_mmp_cds_bback_total
# 149                                   beam_attenuation
# 150                                 optical_absorption
# 151                            error_seawater_velocity
# 152                                                NaN
# 153                                            density
# 154                                 practical_salinity
# 155                                   dissolved_oxygen
# 156                               seawater_temperature
# 157                                  seawater_pressure
# 158                              seawater_conductivity
# 159                                      ctd_tc_oxygen
# 160                       phsen_thermistor_temperature
# 161                    seawater_scattering_coefficient
# 162                                            density
# 163                                 practical_salinity
# 164                               seawater_temperature
# 165                                  seawater_pressure
# 166                              seawater_conductivity
# 167                         corrected_dissolved_oxygen
# 168                       phsen_thermistor_temperature
# 169                    seawater_scattering_coefficient
# 170                           spkir_downwelling_vector
# 171                              nitrate_concentration
# 172                         salinity_corrected_nitrate
# 173                          velpt_d_eastward_velocity
# 174                         velpt_d_northward_velocity
# ..                                                 ...
# 341                                               temp
# 342                                                NaN
# 343                                      thsph_temp_th
# 344                                      thsph_temp_tl
# 345                                           thsph_ph
# 346                                       thsph_ph_acl
# 347                                     thsph_ph_noref
# 348                                 thsph_ph_noref_acl
# 349                                      thsph_sulfide
# 350                                     thsph_hydrogen
# 351                              vent_fluid_temperaure
# 352                           vent_fluid_chloride_conc
# 353                                     vent_fluid_orp
# 354                              trhph_thermistor_temp
# 355                                                NaN
# 356                        corrected_compass_direction
# 357                            seafloor_tilt_magnitude
# 358                            seafloor_tilt_direction
# 359                                    bottom_pressure
# 360                                   botsflu_meanpres
# 361                                  botsflu_meandepth
# 362                                   botsflu_5minrate
# 363                                  botsflu_10minrate
# 364                                   botsflu_predtide
# 365                                   botsflu_daydepth
# 366                                    botsflu_4wkrate
# 367                                    botsflu_8wkrate
# 368                        eastward_turbulent_velocity
# 369                       northward_turbulent_velocity
# 370                          upward_turbulent_velocity
#
# [226 rows x 2 columns]
#
# the following reference designators are missing global range values
#  set()

# %%
request_inputs = request_inputs[['refdes','method','stream','parameter','date']]
request_inputs['date'] = pd.to_datetime(request_inputs['date'])
finaldf['date'] = pd.to_datetime(finaldf['date'])
# finaldf['date'] = finaldf['time_stamp']
finaldf = finaldf[['refdes','parameter','date','data_points','percent']]
new = request_inputs.merge(finaldf, on=(['refdes','parameter','date']),how='outer')
new.to_csv('output/'+array+'_examine.csv', index=False)

# %%
request_inputs
# Out:
#                             refdes          method  \
# 0      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 1      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 2      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 3      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 4      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 5      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 6      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 7      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 8      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 9      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 10     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 11     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 12     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 13     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 14     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 15     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 16     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 17     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 18     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 19     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 20     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 21     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 22     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 23     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 24     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 25     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 26     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 27     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 28     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 29     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# ...                            ...             ...
# 41951  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41952  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41953  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41954  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41955  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41956  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41957  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41958  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41959  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41960  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41961  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41962  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41963  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41964  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41965  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41966  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41967  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41968  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41969  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41970  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41971  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41972  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41973  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41974  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41975  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41976  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41977  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41978  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41979  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41980  RS03AXBS-LJ03A-12-DOSTAD301        streamed
#
#                                     stream      parameter       date
# 0      osmoi_a_subcon_instrument_recovered           temp 2014-09-28
# 1      osmoi_a_subcon_instrument_recovered           temp 2014-09-29
# 2      osmoi_a_subcon_instrument_recovered           temp 2014-09-30
# 3      osmoi_a_subcon_instrument_recovered           temp 2014-10-01
# 4      osmoi_a_subcon_instrument_recovered           temp 2014-10-02
# 5      osmoi_a_subcon_instrument_recovered           temp 2014-10-03
# 6      osmoi_a_subcon_instrument_recovered           temp 2014-10-04
# 7      osmoi_a_subcon_instrument_recovered           temp 2014-10-05
# 8      osmoi_a_subcon_instrument_recovered           temp 2014-10-06
# 9      osmoi_a_subcon_instrument_recovered           temp 2014-10-07
# 10     osmoi_a_subcon_instrument_recovered           temp 2014-10-08
# 11     osmoi_a_subcon_instrument_recovered           temp 2014-10-09
# 12     osmoi_a_subcon_instrument_recovered           temp 2014-10-10
# 13     osmoi_a_subcon_instrument_recovered           temp 2014-10-11
# 14     osmoi_a_subcon_instrument_recovered           temp 2014-10-12
# 15     osmoi_a_subcon_instrument_recovered           temp 2014-10-13
# 16     osmoi_a_subcon_instrument_recovered           temp 2014-10-14
# 17     osmoi_a_subcon_instrument_recovered           temp 2014-10-15
# 18     osmoi_a_subcon_instrument_recovered           temp 2014-10-16
# 19     osmoi_a_subcon_instrument_recovered           temp 2014-10-17
# 20     osmoi_a_subcon_instrument_recovered           temp 2014-10-18
# 21     osmoi_a_subcon_instrument_recovered           temp 2014-10-19
# 22     osmoi_a_subcon_instrument_recovered           temp 2014-10-20
# 23     osmoi_a_subcon_instrument_recovered           temp 2014-10-21
# 24     osmoi_a_subcon_instrument_recovered           temp 2014-10-22
# 25     osmoi_a_subcon_instrument_recovered           temp 2014-10-23
# 26     osmoi_a_subcon_instrument_recovered           temp 2014-10-24
# 27     osmoi_a_subcon_instrument_recovered           temp 2014-10-25
# 28     osmoi_a_subcon_instrument_recovered           temp 2014-10-26
# 29     osmoi_a_subcon_instrument_recovered           temp 2014-10-27
# ...                                    ...            ...        ...
# 41951                  ctdpf_optode_sample  ctd_tc_oxygen 2017-10-29
# 41952                  ctdpf_optode_sample  ctd_tc_oxygen 2017-10-30
# 41953                  ctdpf_optode_sample  ctd_tc_oxygen 2017-10-31
# 41954                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-01
# 41955                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-02
# 41956                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-03
# 41957                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-04
# 41958                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-05
# 41959                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-06
# 41960                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-07
# 41961                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-08
# 41962                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-09
# 41963                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-10
# 41964                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-11
# 41965                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-12
# 41966                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-13
# 41967                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-14
# 41968                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-15
# 41969                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-16
# 41970                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-17
# 41971                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-18
# 41972                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-19
# 41973                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-20
# 41974                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-21
# 41975                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-22
# 41976                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-23
# 41977                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-24
# 41978                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-25
# 41979                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-26
# 41980                  ctdpf_optode_sample  ctd_tc_oxygen 2017-11-27
#
# [41981 rows x 5 columns]

# %%
finaldf
# Out:
#                             refdes                    parameter       date  \
# 0      RS03AXBS-LJ03A-05-HPIESA301       hpies_bliley_frequency 2014-08-24
# 1      RS03AXBS-LJ03A-05-HPIESA301  hpies_bliley_temperature_L1 2014-08-24
# 2      RS03AXBS-LJ03A-05-HPIESA301            hpies_temperature 2014-08-24
# 3      RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time1 2014-08-24
# 4      RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time1_L1 2014-08-24
# 5      RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time2 2014-08-24
# 6      RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time2_L1 2014-08-24
# 7      RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time3 2014-08-24
# 8      RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time3_L1 2014-08-24
# 9      RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time4 2014-08-24
# 10     RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time4_L1 2014-08-24
# 11     RS03AXBS-LJ03A-05-HPIESA301       hpies_bliley_frequency 2014-08-25
# 12     RS03AXBS-LJ03A-05-HPIESA301  hpies_bliley_temperature_L1 2014-08-25
# 13     RS03AXBS-LJ03A-05-HPIESA301            hpies_temperature 2014-08-25
# 14     RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time1 2014-08-25
# 15     RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time1_L1 2014-08-25
# 16     RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time2 2014-08-25
# 17     RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time2_L1 2014-08-25
# 18     RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time3 2014-08-25
# 19     RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time3_L1 2014-08-25
# 20     RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time4 2014-08-25
# 21     RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time4_L1 2014-08-25
# 22     RS03AXBS-LJ03A-05-HPIESA301       hpies_bliley_frequency 2014-08-26
# 23     RS03AXBS-LJ03A-05-HPIESA301  hpies_bliley_temperature_L1 2014-08-26
# 24     RS03AXBS-LJ03A-05-HPIESA301            hpies_temperature 2014-08-26
# 25     RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time1 2014-08-26
# 26     RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time1_L1 2014-08-26
# 27     RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time2 2014-08-26
# 28     RS03AXBS-LJ03A-05-HPIESA301        hpies_travel_time2_L1 2014-08-26
# 29     RS03AXBS-LJ03A-05-HPIESA301           hpies_travel_time3 2014-08-26
# ...                            ...                          ...        ...
# 27589  RS03AXBS-LJ03A-12-CTDPFB301            seawater_pressure 2017-11-19
# 27590  RS03AXBS-LJ03A-12-CTDPFB301         seawater_temperature 2017-11-19
# 28             144    100.0
# 29             144      0.0
# ...            ...      ...
# 27589           51    100.0
# 27590           51    100.0
# 27591           51    100.0
# 27592           51    100.0
# 27593           51    100.0
# 27594           51    100.0
# 27595           51    100.0
# 27596           51    100.0
# 27597           51    100.0
# 27598           51    100.0
# 27599           51    100.0
# 27600           51    100.0
# 27601           51    100.0
# 27602           51    100.0
# 27603           51    100.0
# 27604           51    100.0
# 27605           51    100.0
# 27606           51    100.0
# 27607           51    100.0
# 27608           51    100.0
# 27609           51    100.0
# 27610           51    100.0
# 27611           51    100.0
# 27612           51    100.0
# 27613           51    100.0
# 27614           51    100.0
# 27615           51    100.0
# 27616           51    100.0
# 27617           51    100.0
# 27618           51    100.0
#
# [27619 rows x 5 columns]

# %%
len(request_inputs)
# Out:
# 41981

# %%
new = request_inputs.merge(finaldf, on=(['refdes','parameter','date']),how='outer')

# %%
new.to_csv('output/'+array+'_examine.csv', index=False)

# %%
finaldf = finaldf.reset_index(drop=True)
# Out:
#                             refdes          method  \
# 0      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 1      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 2      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 3      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 4      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 5      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 6      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 7      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 8      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 9      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 10     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 11     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 12     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 13     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 14     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 15     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 16     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 17     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 18     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 19     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 20     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 21     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 22     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 23     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 24     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 25     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 26     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 27     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 28     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 29     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# ...                            ...             ...
# 54238  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54239  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54240  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54241  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54242  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54243  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54244  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54245  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54246  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54247  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54248  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54249  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54250  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54251  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54252  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54253  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54254  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54255  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54256  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54257  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54258  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54259  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54260  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54261  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54262  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54263  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54264  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54265  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54266  RS03AXBS-LJ03A-05-HPIESA301             NaN
# 54267  RS03AXBS-LJ03A-05-HPIESA301             NaN
#
#                                     stream                    parameter  \
# 0      osmoi_a_subcon_instrument_recovered                         temp
# 1      osmoi_a_subcon_instrument_recovered                         temp
# 2      osmoi_a_subcon_instrument_recovered                         temp
# 3      osmoi_a_subcon_instrument_recovered                         temp
# 4      osmoi_a_subcon_instrument_recovered                         temp
# 5      osmoi_a_subcon_instrument_recovered                         temp
# 6      osmoi_a_subcon_instrument_recovered                         temp
# 7      osmoi_a_subcon_instrument_recovered                         temp
# 8      osmoi_a_subcon_instrument_recovered                         temp
# 9      osmoi_a_subcon_instrument_recovered                         temp
# 10     osmoi_a_subcon_instrument_recovered                         temp
# 11     osmoi_a_subcon_instrument_recovered                         temp
# 12     osmoi_a_subcon_instrument_recovered                         temp
# 13     osmoi_a_subcon_instrument_recovered                         temp
# 14     osmoi_a_subcon_instrument_recovered                         temp
# 15     osmoi_a_subcon_instrument_recovered                         temp
# 16     osmoi_a_subcon_instrument_recovered                         temp
# 17     osmoi_a_subcon_instrument_recovered                         temp
# 18     osmoi_a_subcon_instrument_recovered                         temp
# 19     osmoi_a_subcon_instrument_recovered                         temp
# 20     osmoi_a_subcon_instrument_recovered                         temp
# 21     osmoi_a_subcon_instrument_recovered                         temp
# 22     osmoi_a_subcon_instrument_recovered                         temp
# 23     osmoi_a_subcon_instrument_recovered                         temp
# 24     osmoi_a_subcon_instrument_recovered                         temp
# 25     osmoi_a_subcon_instrument_recovered                         temp
# 26     osmoi_a_subcon_instrument_recovered                         temp
# 27     osmoi_a_subcon_instrument_recovered                         temp
# 28     osmoi_a_subcon_instrument_recovered                         temp
# 29     osmoi_a_subcon_instrument_recovered                         temp
# ...                                    ...                          ...
# 54238                                  NaN           hpies_travel_time1
# 54239                                  NaN        hpies_travel_time1_L1
# 54240                                  NaN           hpies_travel_time2
# 54241                                  NaN        hpies_travel_time2_L1
# 54242                                  NaN           hpies_travel_time3
# 54243                                  NaN        hpies_travel_time3_L1
# 54244                                  NaN           hpies_travel_time4
# 54245                                  NaN        hpies_travel_time4_L1
# 54246                                  NaN       hpies_bliley_frequency
# 54247                                  NaN  hpies_bliley_temperature_L1
# 54248                                  NaN            hpies_temperature
# 54249                                  NaN           hpies_travel_time1
# 54250                                  NaN        hpies_travel_time1_L1
# 54251                                  NaN           hpies_travel_time2
# 54252                                  NaN        hpies_travel_time2_L1
# 54253                                  NaN           hpies_travel_time3
# 54254                                  NaN        hpies_travel_time3_L1
# 54255                                  NaN           hpies_travel_time4
# 54256                                  NaN        hpies_travel_time4_L1
# 54257                                  NaN       hpies_bliley_frequency
# 54258                                  NaN  hpies_bliley_temperature_L1
# 54259                                  NaN            hpies_temperature
# 54260                                  NaN           hpies_travel_time1
# 54261                                  NaN        hpies_travel_time1_L1
# 54262                                  NaN           hpies_travel_time2
# 54263                                  NaN        hpies_travel_time2_L1
# 54264                                  NaN           hpies_travel_time3
# 54265                                  NaN        hpies_travel_time3_L1
# 54266                                  NaN           hpies_travel_time4
# 54267                                  NaN        hpies_travel_time4_L1
#
#             date  data_points  percent
# 0     2014-09-28          NaN      NaN
# 1     2014-09-29          NaN      NaN
# 2     2014-09-30          NaN      NaN
# 3     2014-10-01          NaN      NaN
# 4     2014-10-02          NaN      NaN
# 5     2014-10-03          NaN      NaN
# 6     2014-10-04          NaN      NaN
# 7     2014-10-05          NaN      NaN
# 8     2014-10-06          NaN      NaN
# 9     2014-10-07          NaN      NaN
# 10    2014-10-08          NaN      NaN
# 11    2014-10-09          NaN      NaN
# 12    2014-10-10          NaN      NaN
# 13    2014-10-11          NaN      NaN
# 14    2014-10-12          NaN      NaN
# 15    2014-10-13          NaN      NaN
# 16    2014-10-14          NaN      NaN
# 17    2014-10-15          NaN      NaN
# 18    2014-10-16          NaN      NaN
# 19    2014-10-17          NaN      NaN
# 20    2014-10-18          NaN      NaN
# 21    2014-10-19          NaN      NaN
# 22    2014-10-20          NaN      NaN
# 23    2014-10-21          NaN      NaN
# 24    2014-10-22          NaN      NaN
# 25    2014-10-23          NaN      NaN
# 26    2014-10-24          NaN      NaN
# 27    2014-10-25          NaN      NaN
# 28    2014-10-26          NaN      NaN
# 29    2014-10-27          NaN      NaN
# ...          ...          ...      ...
# 54238 2017-11-27        144.0      0.0
# 54239 2017-11-27        144.0    100.0
# 54240 2017-11-27        144.0      0.0
# 54241 2017-11-27        144.0    100.0
# 54242 2017-11-27        144.0      0.0
# 54243 2017-11-27        144.0    100.0
# 54244 2017-11-27        144.0      0.0
# 54245 2017-11-27        144.0    100.0
# 54246 2017-11-25        144.0      0.0
# 54247 2017-11-25        144.0    100.0
# 54248 2017-11-25        144.0    100.0
# 54249 2017-11-25        144.0      0.0
# 54250 2017-11-25        144.0    100.0
# 54251 2017-11-25        144.0      0.0
# 54252 2017-11-25        144.0    100.0
# 54253 2017-11-25        144.0      0.0
# 54254 2017-11-25        144.0    100.0
# 54255 2017-11-25        144.0      0.0
# 54256 2017-11-25        144.0    100.0
# 54257 2017-11-28        144.0      0.0
# 54258 2017-11-28        144.0    100.0
# 54259 2017-11-28        144.0    100.0
# 54260 2017-11-28        144.0      0.0
# 54261 2017-11-28        144.0    100.0
# 54262 2017-11-28        144.0      0.0
# 54263 2017-11-28        144.0    100.0
# 54264 2017-11-28        144.0      0.0
# 54265 2017-11-28        144.0    100.0
# 54266 2017-11-28        144.0      0.0
# 54267 2017-11-28        144.0    100.0
#
# [54268 rows x 7 columns]

# %%
test = request_inputs['refdes'] == 'RS03AXBS-LJ03A-05-HPIESA301'
a = request_inputs[test]

# %%
for i,j in a.iterrows():
    print(j['stream'],j['parameter'])
# Out:
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1
# echo_sounding hpies_pressure_L1

# %%
df3
# Out:
#                         refdes              parameter  time_stamp  \
# 0  RS03AXBS-LJ03A-12-CTDPFB301          ctd_tc_oxygen  2017-11-27
# 1  RS03AXBS-LJ03A-12-CTDPFB301                density  2017-11-27
# 2  RS03AXBS-LJ03A-12-CTDPFB301       dissolved_oxygen  2017-11-27
# 3  RS03AXBS-LJ03A-12-CTDPFB301     practical_salinity  2017-11-27
# 4  RS03AXBS-LJ03A-12-CTDPFB301  seawater_conductivity  2017-11-27
# 5  RS03AXBS-LJ03A-12-CTDPFB301      seawater_pressure  2017-11-27
# 6  RS03AXBS-LJ03A-12-CTDPFB301   seawater_temperature  2017-11-27
#
#    data_points  percent
# 0           51    100.0
# 1           51    100.0
# 2           51    100.0
# 3           51    100.0
# 4           51    100.0
# 5           51    100.0
# 6           51    100.0

# %%
new = a.merge(df3, how='outer')

# %%
new
# Out:
#                         refdes    method               stream  \
# 0  RS03AXBS-LJ03A-12-CTDPFB301  streamed  ctdpf_optode_sample
# 1  RS03AXBS-LJ03A-12-CTDPFB301  streamed  ctdpf_optode_sample
# 2  RS03AXBS-LJ03A-12-CTDPFB301  streamed  ctdpf_optode_sample
# 3  RS03AXBS-LJ03A-12-CTDPFB301  streamed  ctdpf_optode_sample
# 4  RS03AXBS-LJ03A-12-CTDPFB301  streamed  ctdpf_optode_sample
# 5  RS03AXBS-LJ03A-12-CTDPFB301  streamed  ctdpf_optode_sample
# 6  RS03AXBS-LJ03A-12-CTDPFB301  streamed  ctdpf_optode_sample
#
#                parameter  time_stamp  data_points  percent
# 0                density  2017-11-27           51    100.0
# 1     practical_salinity  2017-11-27           51    100.0
# 2       dissolved_oxygen  2017-11-27           51    100.0
# 3   seawater_temperature  2017-11-27           51    100.0
# 4      seawater_pressure  2017-11-27           51    100.0
# 5  seawater_conductivity  2017-11-27           51    100.0
# 6          ctd_tc_oxygen  2017-11-27           51    100.0

# %%
request_inputs
# Out:
#                             refdes          method  \
# 0      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 1      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 2      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 3      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 4      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 5      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 6      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 7      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 8      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 9      RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 10     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 11     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 12     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 13     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 14     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 15     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 16     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 17     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 18     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 19     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 20     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 21     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 22     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 23     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 24     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 25     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 26     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 27     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 28     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# 29     RS03ASHS-MJ03B-00-OSMOIA301  recovered_inst
# ...                            ...             ...
# 41951  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41952  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41953  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41954  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41955  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41956  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41957  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41958  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41959  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41960  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41961  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41962  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41963  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41964  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41965  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41966  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41967  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41968  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41969  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41970  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41971  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41972  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41973  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41974  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41975  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41976  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41977  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41978  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41979  RS03AXBS-LJ03A-12-DOSTAD301        streamed
# 41980  RS03AXBS-LJ03A-12-DOSTAD301        streamed
#
#                                     stream      parameter deployment  \
# 0      osmoi_a_subcon_instrument_recovered           temp          1
# 1      osmoi_a_subcon_instrument_recovered           temp          1
# 2      osmoi_a_subcon_instrument_recovered           temp          1
# 3      osmoi_a_subcon_instrument_recovered           temp          1
# 4      osmoi_a_subcon_instrument_recovered           temp          1
# 5      osmoi_a_subcon_instrument_recovered           temp          1
# 6      osmoi_a_subcon_instrument_recovered           temp          1
# 7      osmoi_a_subcon_instrument_recovered           temp          1
# 8      osmoi_a_subcon_instrument_recovered           temp          1
# 9      osmoi_a_subcon_instrument_recovered           temp          1
# 10     osmoi_a_subcon_instrument_recovered           temp          1
# 11     osmoi_a_subcon_instrument_recovered           temp          1
# 12     osmoi_a_subcon_instrument_recovered           temp          1
# 13     osmoi_a_subcon_instrument_recovered           temp          1
# 14     osmoi_a_subcon_instrument_recovered           temp          1
# 15     osmoi_a_subcon_instrument_recovered           temp          1
# 16     osmoi_a_subcon_instrument_recovered           temp          1
# 17     osmoi_a_subcon_instrument_recovered           temp          1
# 18     osmoi_a_subcon_instrument_recovered           temp          1
# 19     osmoi_a_subcon_instrument_recovered           temp          1
# 20     osmoi_a_subcon_instrument_recovered           temp          1
# 21     osmoi_a_subcon_instrument_recovered           temp          1
# 22     osmoi_a_subcon_instrument_recovered           temp          1
# 23     osmoi_a_subcon_instrument_recovered           temp          1
# 24     osmoi_a_subcon_instrument_recovered           temp          1
# 25     osmoi_a_subcon_instrument_recovered           temp          1
# 26     osmoi_a_subcon_instrument_recovered           temp          1
# 27     osmoi_a_subcon_instrument_recovered           temp          1
# 28     osmoi_a_subcon_instrument_recovered           temp          1
# 29     osmoi_a_subcon_instrument_recovered           temp          1
# ...                                    ...            ...        ...
# 41951                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41952                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41953                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41954                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41955                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41956                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41957                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41958                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41959                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41960                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41961                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41962                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41963                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41964                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41965                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41966                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41967                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41968                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41969                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41970                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41971                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41972                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41973                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41974                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41975                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41976                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41977                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 41978                  ctdpf_optode_sample  ctd_tc_oxygen          4
# 
# 1      https://ooinet.oceanobservatories.org/api/m2m/...
# 2      https://ooinet.oceanobservatories.org/api/m2m/...
# 3      https://ooinet.oceanobservatories.org/api/m2m/...
# 4      https://ooinet.oceanobservatories.org/api/m2m/...
# 5      https://ooinet.oceanobservatories.org/api/m2m/...
# 6      https://ooinet.oceanobservatories.org/api/m2m/...
# 7      https://ooinet.oceanobservatories.org/api/m2m/...
# 8      https://ooinet.oceanobservatories.org/api/m2m/...
# 9      https://ooinet.oceanobservatories.org/api/m2m/...
# 10     https://ooinet.oceanobservatories.org/api/m2m/...
# 11     https://ooinet.oceanobservatories.org/api/m2m/...
# 12     https://ooinet.oceanobservatories.org/api/m2m/...
# 13     https://ooinet.oceanobservatories.org/api/m2m/...
# 14     https://ooinet.oceanobservatories.org/api/m2m/...
# 15     https://ooinet.oceanobservatories.org/api/m2m/...
# 16     https://ooinet.oceanobservatories.org/api/m2m/...
# 17     https://ooinet.oceanobservatories.org/api/m2m/...
# 18     https://ooinet.oceanobservatories.org/api/m2m/...
# 19     https://ooinet.oceanobservatories.org/api/m2m/...
# 20     https://ooinet.oceanobservatories.org/api/m2m/...
# 21     https://ooinet.oceanobservatories.org/api/m2m/...
# 22     https://ooinet.oceanobservatories.org/api/m2m/...
# 23     https://ooinet.oceanobservatories.org/api/m2m/...
# 24     https://ooinet.oceanobservatories.org/api/m2m/...
# 25     https://ooinet.oceanobservatories.org/api/m2m/...
# 26     https://ooinet.oceanobservatories.org/api/m2m/...
# 27     https://ooinet.oceanobservatories.org/api/m2m/...
# 28     https://ooinet.oceanobservatories.org/api/m2m/...
# 29     https://ooinet.oceanobservatories.org/api/m2m/...
# ...                                                  ...
# 41951  https://ooinet.oceanobservatories.org/api/m2m/...
# 41952  https://ooinet.oceanobservatories.org/api/m2m/...
# 41953  https://ooinet.oceanobservatories.org/api/m2m/...
# 41954  https://ooinet.oceanobservatories.org/api/m2m/...
# 41955  https://ooinet.oceanobservatories.org/api/m2m/...
# 41956  https://ooinet.oceanobservatories.org/api/m2m/...
# 41957  https://ooinet.oceanobservatories.org/api/m2m/...
# 41958  https://ooinet.oceanobservatories.org/api/m2m/...
# 41959  https://ooinet.oceanobservatories.org/api/m2m/...
# 41960  https://ooinet.oceanobservatories.org/api/m2m/...
# 41961  https://ooinet.oceanobservatories.org/api/m2m/...
# 41962  https://ooinet.oceanobservatories.org/api/m2m/...
# 41963  https://ooinet.oceanobservatories.org/api/m2m/...
# 41964  https://ooinet.oceanobservatories.org/api/m2m/...
# 41965  https://ooinet.oceanobservatories.org/api/m2m/...
# 41966  https://ooinet.oceanobservatories.org/api/m2m/...
# 41967  https://ooinet.oceanobservatories.org/api/m2m/...
# 41968  https://ooinet.oceanobservatories.org/api/m2m/...
# 41969  https://ooinet.oceanobservatories.org/api/m2m/...
# 41970  https://ooinet.oceanobservatories.org/api/m2m/...
# 41971  https://ooinet.oceanobservatories.org/api/m2m/...
# 41972  https://ooinet.oceanobservatories.org/api/m2m/...
# 41973  https://ooinet.oceanobservatories.org/api/m2m/...
# 41974  https://ooinet.oceanobservatories.org/api/m2m/...
# 41975  https://ooinet.oceanobservatories.org/api/m2m/...
# 41976  https://ooinet.oceanobservatories.org/api/m2m/...
# 41977  https://ooinet.oceanobservatories.org/api/m2m/...
# 41978  https://ooinet.oceanobservatories.org/api/m2m/...
# 41979  https://ooinet.oceanobservatories.org/api/m2m/...
# 41980  https://ooinet.oceanobservatories.org/api/m2m/...
#
# [41981 rows x 12 columns]

# %%
# %%time

finaldf = pd.DataFrame()
missing = []

data_request_url = DATA_URL+\
                    'RS03ASHS/'+\
                    'MJ03B/'+\
                    '07-TMPSFA301/'+\
                    'streamed/'+\
                    'tmpsf_sample'+'?'+\
                    'beginDT=2017-09-04T17:54:58.050Z&'+\
                    'endDT=2017-09-11T23:54:58.050Z&'+\
                    'limit=50'
                    
r = requests.get(data_request_url, auth=(username, token))
data = r.json()

refdes_list = []
parameter_list = []
timestamp_list = []
value_list = []

# iterate through data points to extract time stamps
for i in range(len(data)):
    timestamp = data[i]['time']
    timestamp = datetime.datetime.utcfromtimestamp(timestamp - ntp_delta).replace(microsecond=0)
    timestamp = timestamp.date()

    # get refdes from the response and create data frame y with the corresponding gloabl range values
    refdes = data[i]['pk']['subsite'] + '-' + data[i]['pk']['node'] + '-' + data[i]['pk']['sensor']
    x = global_ranges['refdes'] == refdes
    y = global_ranges[x]

    # check if global range list contains an entry for the refdes
    templist = list(global_ranges['refdes'])
    if refdes not in templist:
        missing.append(refdes)


    # iterate through all variables in global range data frame y, then iterate through keys in data point
    # to find matching keys, then grab values
    for var in y.parameter.values:
        for j in data[i].keys():
            if var == j:
                z = data[i][j]

                # conditional to handle 2d datasets, in which case the first non nan value is checked
                if type(z) != list:
                    refdes_list.append(refdes)
                    parameter_list.append(var)
                    value_list.append(z)
                    timestamp_list.append(timestamp)
                else:
                    u = next(u for u in z if not isnan(u))
                    refdes_list.append(refdes)
                    parameter_list.append(var)
                    value_list.append(u)
                    timestamp_list.append(timestamp)


    # create data frame from lists collected above
    data_dict = {
        'refdes':refdes_list,
        'parameter':parameter_list,
        'value':value_list,
        'date':timestamp_list}
    response_data = pd.DataFrame(data_dict, columns = ['refdes','parameter','value','date'])

    # merge into data frame with global range values and check if value between global ranges
    df = y.merge(response_data,how='outer')
    df['pass'] = (df['value'] < pd.to_numeric(df['global_range_max'])) & \
                    (df['value'] > pd.to_numeric(df['global_range_min']))

    # collapse the data frame to calculate percent of data points that pass the test for that day
    df2 = df['pass'].groupby([df['refdes'], \
                df['parameter'],\
              df['date'] \
               ]).sum().reset_index()
    df2['percent'] = (df2['pass'] / len(data)) * 100

    # append result for this ref des and day to final data frame
    finaldf = finaldf.append(df2)
# Out:
# CPU times: user 836 ms, sys: 9.41 ms, total: 846 ms
# Wall time: 2.6 s

# %%
len(df)
# Out:
# 24024

# %%
len(data)
# Out:
# 1001

# %%
)
# Out:
# 24024
