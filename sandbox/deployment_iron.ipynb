# %%
# %%time
import matplotlib.pyplot as plt
import requests
from requests.packages.urllib3.util.retry import Retry
import json
import datetime
import pandas as pd
import concurrent.futures
import logging
import gc


# define your inputs
username = 'OOIAPI-30AZZ33CYL06XZ'
token = 'GPJJ7ACBPR9'
arrays = ['test']


# set up some functions
def request_data(url,username,token):
    auth = (username, token)
    return session.get(url,auth=auth)

def to_integer(dt_time):
    return 10000*dt_time.year + 100*dt_time.month + dt_time.day

def diff_days(d1,d2):
    return (d2 - d1).days


# base url for the request that will be built using the inputs above.
DEPLOYEMENT_URL = 'https://ooinet.oceanobservatories.org/api/m2m/12587/events/deployment/inv/'
DATA_URL = 'https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/'
parameter = '7'

ntp_epoch = datetime.datetime(1900, 1, 1)
unix_epoch = datetime.datetime(1970, 1, 1)
ntp_delta = (unix_epoch - ntp_epoch).total_seconds()

pool = concurrent.futures.ThreadPoolExecutor(max_workers=20)
session = requests.session()
retry = Retry(
        total=10,
        backoff_factor=0.3,
    )
adapter = requests.adapters.HTTPAdapter(pool_connections=100, pool_maxsize=100,max_retries=retry,pool_block=True)
session.mount('http://', adapter)


for array in arrays:

    logging.basicConfig(filename=array+'_requests.log',level=logging.DEBUG)

    refdes = 'input/' + array + '.csv'
    refdes_list = pd.read_csv(refdes)
    refdes_list = refdes_list['refdes']
    refdes_list = refdes_list.drop_duplicates()

    print('\n'+"working on", array)
    print("building deployment info requests...")
    asset_requests = []
    for i in refdes_list:
        sub_site = i[:8]
        platform = i[9:14]
        instrument = i[15:27]
        asset_url_inputs = '/'.join((sub_site, platform, instrument))
        request_url = DEPLOYEMENT_URL+asset_url_inputs+'/-1'
        asset_requests.append(request_url)

    print("sending deployment info requests...")
    ref_des_list = []
    start_time_list = []
    end_time_list = []
    deployment_list = []

    future_to_url = {pool.submit(request_data, url, username, token): url for url in asset_requests}
    for future in concurrent.futures.as_completed(future_to_url):
        try:
            asset_info = future.result()
            asset_info = asset_info.json()
            
            for i in range(len(asset_info)):
                refdes = asset_info[i]['referenceDesignator']
                ref_des_list.append(refdes)
                
                deployment = asset_info[i]['deploymentNumber']
                deployment_list.append(deployment)
                
                start = asset_info[i]['eventStartTime']
                end = asset_info[i]['eventStopTime']
                
                try:
                    start_time = datetime.datetime.utcfromtimestamp(start/1000.0)
                    start_time_list.append(start_time)
                    
                    end_time = datetime.datetime.utcfromtimestamp(end/1000.0)
                    end_time_list.append(end_time)
                    
                except:
                    end_time = datetime.datetime.utcnow()
                    end_time_list.append(end_time)
                    
        except:
            pass

    data_dict = {
        'refdes':ref_des_list,
        'deployment':deployment_list,
        'start_time':start_time_list,
        'end_time':end_time_list}
    deployment_data = pd.DataFrame(data_dict, columns = ['refdes', 'deployment','start_time', 'end_time'])



    print("calculating days between deployment dates...")
    deployment_data_days = pd.DataFrame(columns = ['refdes', 'deployment','date'])

    # calculate days between deployment dates
    for index, row in deployment_data.iterrows():
        start_time = row['start_time']
        end_time = row['end_time']
        periods = diff_days(start_time, end_time)
        start_time = to_integer(start_time)
        total_days = pd.DataFrame({'date' : pd.date_range(str(start_time),periods=periods,freq='D')})
        
        total_days['refdes'] = row['refdes']
        total_days['deployment'] = row['deployment']
        deployment_data_days = deployment_data_days.append(total_days)

    # re-order data frame columns
    deployment_data_days = deployment_data_days[['refdes', 'deployment','date']]







    print("building data request urls...")
    deployment_data_days['start_date'] = deployment_data_days['date'] + datetime.timedelta(seconds=5)
    deployment_data_days['end_date'] = deployment_data_days['date'] + datetime.timedelta(seconds=86395)

    refdes_streams = 'input/' + array + '.csv'
    refdes_streams_df = pd.read_csv(refdes_streams)

    request_inputs = pd.merge(refdes_streams_df,deployment_data_days, on='refdes')

    request_inputs['subsite'] = request_inputs.refdes.str[:8]
    request_inputs['platform'] = request_inputs.refdes.str[9:14]
    request_inputs['instrument'] = request_inputs.refdes.str[15:27]
    request_inputs['start_date'] = pd.to_datetime(request_inputs['start_date'])
    request_inputs['start_date'] = request_inputs.start_date.dt.strftime('%Y-%m-%dT%H:%M:%S.000Z')
    request_inputs['end_date'] = pd.to_datetime(request_inputs['end_date'])
    request_inputs['end_date'] = request_inputs.end_date.dt.strftime('%Y-%m-%dT%H:%M:%S.000Z')

    request_inputs['urls'] = DATA_URL+\
                            request_inputs.subsite+\
                            '/'+request_inputs.platform+\
                            '/'+request_inputs.instrument+\
                            '/'+request_inputs.method+\
                            '/'+request_inputs.stream+\
                            '?beginDT='+request_inputs.start_date+\
                            '&endDT='+request_inputs.end_date+\
                            '&limit=1000&parameters='+parameter
                            
#     request_inputs = request_inputs[['urls']]
#     request_inputs_test = request_inputs.drop_duplicates()

    request_urls = request_inputs['urls'].values.tolist()


    print("sending data requests for", array+'...')
    print('\t',"current time:", datetime.datetime.now())
    print('\t',len(request_urls ),"data requests being sent")
    print('\t',"check",array+"_requests.log","file in your working directory for progress")


    ref_des_list = []
    deployment_list = []
    method_list = []
    stream_list = []
    timestamp_list = []
    
    urls_test = []


    future_to_url = {pool.submit(request_data, url, username, token): url for url in request_urls}
    for future in concurrent.futures.as_completed(future_to_url):
#         url = future_to_url[future]
        try: 
            data = future.result() 
            data = data.json()
            reference_designator = data[5]['pk']['subsite'] + '-' + data[5]['pk']['node'] + '-' + data[5]['pk']['sensor']
            deployment = data[5]['pk']['deployment']
            method = data[5]['pk']['method']
            stream = data[5]['pk']['stream']
            timestamp = data[5]['time']
            timestamp = datetime.datetime.utcfromtimestamp(timestamp - ntp_delta).replace(microsecond=0)
            timestamp = timestamp.date()
            # print(reference_designator, deployment, method, stream, timestamp, future.result())

            ref_des_list.append(reference_designator)
            deployment_list.append(deployment)
            method_list.append(method)
            stream_list.append(stream)
            timestamp_list.append(timestamp)
            
#             urls_test.append(url)

        except:
#             print('no data for ', url)
            pass






    # convert lists to data frame
    data_dict = {
        'refdes':ref_des_list,
#         'deployment':deployment_list,
        'method':method_list,
        'stream':stream_list,
        'date':timestamp_list}
    ooi_data = pd.DataFrame(data_dict, columns = ['refdes','method','stream', 'date'])
    ooi_data = ooi_data.drop_duplicates() # drops days from overlapping deployment time ranges
    ooi_data['date'] = pd.to_datetime(ooi_data['date'])
    ooi_data['date'] = ooi_data.date.dt.strftime('%Y-%m-%d')

    request_inputs = request_inputs[['refdes','method','stream', 'date']]
    request_inputs = request_inputs.drop_duplicates() # drops days from overlapping deployment time ranges
    request_inputs['date'] = pd.to_datetime(request_inputs['date'])
    request_inputs['date'] = request_inputs.date.dt.strftime('%Y-%m-%d')

    deployed_but_no_data = ooi_data.merge(request_inputs,indicator=True, how='outer')
    deployed_but_no_data = deployed_but_no_data[deployed_but_no_data['_merge'] == 'right_only']
    del deployed_but_no_data['_merge']

    deployed_but_no_data['value'] = 0
    ooi_data['value'] = 1

    output = pd.concat([ooi_data, deployed_but_no_data])
# Out:
# working on test
# building deployment info requests...
# sending deployment info requests...
# calculating days between deployment dates...
# building data request urls...
# sending data requests for test...
# 	 current time: 2017-11-10 13:10:30.646433
# 	 1162 data requests being sent
# 	 check test_requests.log file in your working directory for progress
# CPU times: user 7.6 s, sys: 601 ms, total: 8.2 s
# Wall time: 1min 26s

# %%
output
# Out:
#                            refdes         method  \
# 0     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 2     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 3     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 4     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 5     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 6     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 7     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 8     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 9     GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 10    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 11    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 12    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 13    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 14    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 15    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 16    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 17    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 18    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 19    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 20    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 21    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 22    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 23    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 24    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 25    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 26    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 27    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 28    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 29    GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# ...                           ...            ...
# 1125  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1126  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1127  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1128  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1129  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1130  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1131  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1132  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1133  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1134  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1135  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1136  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1137  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1138  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1139  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1140  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1141  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1142  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1143  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1144  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1145  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1146  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1147  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1148  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1149  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1150  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1151  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1152  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1153  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1154  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
#
#                                   stream        date  value
# 0     ctdpf_ckl_wfp_instrument_recovered  2014-09-18      1
# 1     ctdpf_ckl_wfp_instrument_recovered  2014-09-16      1
# 2     ctdpf_ckl_wfp_instrument_recovered  2014-09-22      1
# 3     ctdpf_ckl_wfp_instrument_recovered  2014-09-30      1
# 4     ctdpf_ckl_wfp_instrument_recovered  2014-09-13      1
# 5     ctdpf_ckl_wfp_instrument_recovered  2014-09-12      1
# 6     ctdpf_ckl_wfp_instrument_recovered  2014-10-01      1
# 7     ctdpf_ckl_wfp_instrument_recovered  2014-09-28      1
# 8     ctdpf_ckl_wfp_instrument_recovered  2014-09-17      1
# 9     ctdpf_ckl_wfp_instrument_recovered  2014-09-27      1
# 10    ctdpf_ckl_wfp_instrument_recovered  2014-09-23      1
# 11    ctdpf_ckl_wfp_instrument_recovered  2014-09-20      1
# 12    ctdpf_ckl_wfp_instrument_recovered  2014-09-21      1
# 13    ctdpf_ckl_wfp_instrument_recovered  2014-09-14      1
# 14    ctdpf_ckl_wfp_instrument_recovered  2014-09-29      1
# 15    ctdpf_ckl_wfp_instrument_recovered  2014-10-05      1
# 16    ctdpf_ckl_wfp_instrument_recovered  2014-10-03      1
# 17    ctdpf_ckl_wfp_instrument_recovered  2014-09-25      1
# 18    ctdpf_ckl_wfp_instrument_recovered  2014-09-19      1
# 19    ctdpf_ckl_wfp_instrument_recovered  2014-09-26      1
# 20    ctdpf_ckl_wfp_instrument_recovered  2014-09-24      1
# 21    ctdpf_ckl_wfp_instrument_recovered  2014-09-15      1
# 22    ctdpf_ckl_wfp_instrument_recovered  2014-10-07      1
# 23    ctdpf_ckl_wfp_instrument_recovered  2014-10-13      1
# 24    ctdpf_ckl_wfp_instrument_recovered  2014-10-17      1
# 25    ctdpf_ckl_wfp_instrument_recovered  2014-10-09      1
# 26    ctdpf_ckl_wfp_instrument_recovered  2014-10-08      1
# 27    ctdpf_ckl_wfp_instrument_recovered  2014-10-02      1
# 28    ctdpf_ckl_wfp_instrument_recovered  2014-10-14      1
# 29    ctdpf_ckl_wfp_instrument_recovered  2014-10-10      1
# ...                                  ...         ...    ...
# 1125  ctdpf_ckl_wfp_instrument_recovered  2017-10-11      0
# 1126  ctdpf_ckl_wfp_instrument_recovered  2017-10-12      0
# 1127  ctdpf_ckl_wfp_instrument_recovered  2017-10-13      0
# 1128  ctdpf_ckl_wfp_instrument_recovered  2017-10-14      0
# 1129  ctdpf_ckl_wfp_instrument_recovered  2017-10-15      0
# 1130  ctdpf_ckl_wfp_instrument_recovered  2017-10-16      0
# 1131  ctdpf_ckl_wfp_instrument_recovered  2017-10-17      0
# 1132  ctdpf_ckl_wfp_instrument_recovered  2017-10-18      0
# 1133  ctdpf_ckl_wfp_instrument_recovered  2017-10-19      0
# 1134  ctdpf_ckl_wfp_instrument_recovered  2017-10-20      0
# 1135  ctdpf_ckl_wfp_instrument_recovered  2017-10-21      0
# 1136  ctdpf_ckl_wfp_instrument_recovered  2017-10-22      0
# 1137  ctdpf_ckl_wfp_instrument_recovered  2017-10-23      0
# 1138  ctdpf_ckl_wfp_instrument_recovered  2017-10-24      0
# 1139  ctdpf_ckl_wfp_instrument_recovered  2017-10-25      0
# 1140  ctdpf_ckl_wfp_instrument_recovered  2017-10-26      0
# 1141  ctdpf_ckl_wfp_instrument_recovered  2017-10-27      0
# 1142  ctdpf_ckl_wfp_instrument_recovered  2017-10-28      0
# 1143  ctdpf_ckl_wfp_instrument_recovered  2017-10-29      0
# 1144  ctdpf_ckl_wfp_instrument_recovered  2017-10-30      0
# 1145  ctdpf_ckl_wfp_instrument_recovered  2017-10-31      0
# 1146  ctdpf_ckl_wfp_instrument_recovered  2017-11-01      0
# 1147  ctdpf_ckl_wfp_instrument_recovered  2017-11-02      0
# 1148  ctdpf_ckl_wfp_instrument_recovered  2017-11-03      0
# 1149  ctdpf_ckl_wfp_instrument_recovered  2017-11-04      0
# 1150  ctdpf_ckl_wfp_instrument_recovered  2017-11-05      0
# 1151  ctdpf_ckl_wfp_instrument_recovered  2017-11-06      0
# 1152  ctdpf_ckl_wfp_instrument_recovered  2017-11-07      0
# 1153  ctdpf_ckl_wfp_instrument_recovered  2017-11-08      0
# 1154  ctdpf_ckl_wfp_instrument_recovered  2017-11-09      0
#
# [1155 rows x 5 columns]

# %%
final = output[output.duplicated(keep=False)]

# %%
final
# Out:
# Empty DataFrame
# Columns: [refdes, method, stream, date, value]
# Index: []

# %%
output.to_csv('output/'+array+'.csv', index=False)

# %%
urls = urls[urls.duplicated(keep=False)]

# %%
urls
# Out:
#                                                    urls
# 668   https://ooinet.oceanobservatories.org/api/m2m/...
# 669   https://ooinet.oceanobservatories.org/api/m2m/...
# 670   https://ooinet.oceanobservatories.org/api/m2m/...
# 671   https://ooinet.oceanobservatories.org/api/m2m/...
# 672   https://ooinet.oceanobservatories.org/api/m2m/...
# 673   https://ooinet.oceanobservatories.org/api/m2m/...
# 674   https://ooinet.oceanobservatories.org/api/m2m/...
# 675   https://ooinet.oceanobservatories.org/api/m2m/...
# 1063  https://ooinet.oceanobservatories.org/api/m2m/...
# 1064  https://ooinet.oceanobservatories.org/api/m2m/...
# 1065  https://ooinet.oceanobservatories.org/api/m2m/...
# 1066  https://ooinet.oceanobservatories.org/api/m2m/...
# 1067  https://ooinet.oceanobservatories.org/api/m2m/...
# 1068  https://ooinet.oceanobservatories.org/api/m2m/...

# %%
request_inputs[1060:1070]
# Out:
#                            refdes         method  \
# 1060  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1061  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1062  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1063  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1064  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1065  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1066  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1067  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1068  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
# 1069  GI02HYPM-WFP02-04-CTDPFL000  recovered_wfp
#
#                                   stream deployment       date  \
# 1060  ctdpf_ckl_wfp_instrument_recovered          3 2017-08-03
# 1061  ctdpf_ckl_wfp_instrument_recovered          3 2017-08-04
# 1062  ctdpf_ckl_wfp_instrument_recovered          3 2017-08-05
# 1063  ctdpf_ckl_wfp_instrument_recovered          3 2017-08-06
# 1064  ctdpf_ckl_wfp_instrument_recovered          3 2017-08-07
# 1065  ctdpf_ckl_wfp_instrument_recovered          3 2017-08-08
# 1066  ctdpf_ckl_wfp_instrument_recovered          4 2017-08-06
# 1067  ctdpf_ckl_wfp_instrument_recovered          4 2017-08-07
# 1068  ctdpf_ckl_wfp_instrument_recovered          4 2017-08-08
# 1069  ctdpf_ckl_wfp_instrument_recovered          4 2017-08-09
#
#                     start_date                  end_date   subsite platform  \
# 1060  2017-08-03T00:00:05.000Z  2017-08-03T23:59:55.000Z  GI02HYPM    WFP02
# 1061  2017-08-04T00:00:05.000Z  2017-08-04T23:59:55.000Z  GI02HYPM    WFP02
# 1062  2017-08-05T00:00:05.000Z  2017-08-05T23:59:55.000Z  GI02HYPM    WFP02
# 1063  2017-08-06T00:00:05.000Z  2017-08-06T23:59:55.000Z  GI02HYPM    WFP02
# 1064  2017-08-07T00:00:05.000Z  2017-08-07T23:59:55.000Z  GI02HYPM    WFP02
# 1065  2017-08-08T00:00:05.000Z  2017-08-08T23:59:55.000Z  GI02HYPM    WFP02
# 1066  2017-08-06T00:00:05.000Z  2017-08-06T23:59:55.000Z  GI02HYPM    WFP02
# 1067  2017-08-07T00:00:05.000Z  2017-08-07T23:59:55.000Z  GI02HYPM    WFP02
# 1068  2017-08-08T00:00:05.000Z  2017-08-08T23:59:55.000Z  GI02HYPM    WFP02
# 1069  2017-08-09T00:00:05.000Z  2017-08-09T23:59:55.000Z  GI02HYPM    WFP02
#
#         instrument                                               urls
# 1060  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1061  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1062  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1063  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1064  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1065  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1066  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1067  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1068  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...
# 1069  04-CTDPFL000  https://ooinet.oceanobservatories.org/api/m2m/...

# %%
urls_test = pd.DataFrame(urls_test)
sent_urls = urls_test[urls_test.duplicated(keep=False)]

# %%
sent_urls
# Out:
#                                                      0
# 652  https://ooinet.oceanobservatories.org/api/m2m/...
# 653  https://ooinet.oceanobservatories.org/api/m2m/...
# 655  https://ooinet.oceanobservatories.org/api/m2m/...
# 659  https://ooinet.oceanobservatories.org/api/m2m/...
# 661  https://ooinet.oceanobservatories.org/api/m2m/...
# 666  https://ooinet.oceanobservatories.org/api/m2m/...

# %%
trial = ooi_data[ooi_data.duplicated(keep=False)]

# %%
trial
# Out:
#                            refdes  deployment         method  \
# 0     GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 4     GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 5     GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 7     GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 12    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 14    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 17    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 18    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 20    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 25    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 28    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 31    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 32    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 36    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 42    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 46    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 52    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 55    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 57    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 60    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 62    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 68    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 70    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 73    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 79    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 83    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 85    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 87    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 93    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# 95    GI02HYPM-WFP02-04-CTDPFL000           1  recovered_wfp
# ...                           ...         ...            ...
# 964   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 966   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 967   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 969   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 973   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 976   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 977   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 979   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 980   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 981   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 982   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 985   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 987   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 989   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 992   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 993   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 994   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 995   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 997   GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1000  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1004  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1006  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1007  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1010  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1011  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1012  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1015  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1016  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1017  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
# 1019  GI02HYPM-WFP02-04-CTDPFL000           3  recovered_wfp
#
#                                   stream        date  value
# 0     ctdpf_ckl_wfp_instrument_recovered  2014-09-29      1
# 4     ctdpf_ckl_wfp_instrument_recovered  2014-09-15      1
# 5     ctdpf_ckl_wfp_instrument_recovered  2014-09-12      1
# 7     ctdpf_ckl_wfp_instrument_recovered  2014-09-12      1
# 12    ctdpf_ckl_wfp_instrument_recovered  2014-09-15      1
# 14    ctdpf_ckl_wfp_instrument_recovered  2014-09-29      1
# 17    ctdpf_ckl_wfp_instrument_recovered  2014-10-06      1
# 18    ctdpf_ckl_wfp_instrument_recovered  2014-09-22      1
# 20    ctdpf_ckl_wfp_instrument_recovered  2014-09-22      1
# 25    ctdpf_ckl_wfp_instrument_recovered  2014-10-06      1
# 28    ctdpf_ckl_wfp_instrument_recovered  2014-10-20      1
# 31    ctdpf_ckl_wfp_instrument_recovered  2014-10-20      1
# 32    ctdpf_ckl_wfp_instrument_recovered  2014-10-13      1
# 36    ctdpf_ckl_wfp_instrument_recovered  2014-10-13      1
# 42    ctdpf_ckl_wfp_instrument_recovered  2014-10-27      1
# 46    ctdpf_ckl_wfp_instrument_recovered  2014-11-03      1
# 52    ctdpf_ckl_wfp_instrument_recovered  2014-10-27      1
# 55    ctdpf_ckl_wfp_instrument_recovered  2014-11-03      1
# 57    ctdpf_ckl_wfp_instrument_recovered  2014-11-17      1
# 60    ctdpf_ckl_wfp_instrument_recovered  2014-11-10      1
# 62    ctdpf_ckl_wfp_instrument_recovered  2014-11-10      1
# 68    ctdpf_ckl_wfp_instrument_recovered  2014-11-24      1
# 70    ctdpf_ckl_wfp_instrument_recovered  2014-11-17      1
# 73    ctdpf_ckl_wfp_instrument_recovered  2014-12-01      1
# 79    ctdpf_ckl_wfp_instrument_recovered  2014-11-24      1
# 83    ctdpf_ckl_wfp_instrument_recovered  2014-12-01      1
# 85    ctdpf_ckl_wfp_instrument_recovered  2014-12-08      1
# 87    ctdpf_ckl_wfp_instrument_recovered  2014-12-15      1
# 93    ctdpf_ckl_wfp_instrument_recovered  2014-12-08      1
# 95    ctdpf_ckl_wfp_instrument_recovered  2014-12-15      1
# ...                                  ...         ...    ...
# 964   ctdpf_ckl_wfp_instrument_recovered  2017-05-19      1
# 966   ctdpf_ckl_wfp_instrument_recovered  2017-05-22      1
# 967   ctdpf_ckl_wfp_instrument_recovered  2017-05-22      1
# 969   ctdpf_ckl_wfp_instrument_recovered  2017-05-15      1
# 973   ctdpf_ckl_wfp_instrument_recovered  2017-05-29      1
# 976   ctdpf_ckl_wfp_instrument_recovered  2017-05-24      1
# 977   ctdpf_ckl_wfp_instrument_recovered  2017-06-05      1
# 979   ctdpf_ckl_wfp_instrument_recovered  2017-06-08      1
# 980   ctdpf_ckl_wfp_instrument_recovered  2017-06-08      1
# 981   ctdpf_ckl_wfp_instrument_recovered  2017-05-24      1
# 982   ctdpf_ckl_wfp_instrument_recovered  2017-05-29      1
# 985   ctdpf_ckl_wfp_instrument_recovered  2017-06-03      1
# 987   ctdpf_ckl_wfp_instrument_recovered  2017-06-05      1
# 989   ctdpf_ckl_wfp_instrument_recovered  2017-06-03      1
# 992   ctdpf_ckl_wfp_instrument_recovered  2017-06-19      1
# 993   ctdpf_ckl_wfp_instrument_recovered  2017-06-19      1
# 994   ctdpf_ckl_wfp_instrument_recovered  2017-06-23      1
# 995   ctdpf_ckl_wfp_instrument_recovered  2017-06-13      1
# 997   ctdpf_ckl_wfp_instrument_recovered  2017-06-13      1
# 1000  ctdpf_ckl_wfp_instrument_recovered  2017-06-26      1
# 1004  ctdpf_ckl_wfp_instrument_recovered  2017-06-28      1
# 1006  ctdpf_ckl_wfp_instrument_recovered  2017-06-23      1
# 1007  ctdpf_ckl_wfp_instrument_recovered  2017-07-03      1
# 1010  ctdpf_ckl_wfp_instrument_recovered  2017-06-26      1
# 1011  ctdpf_ckl_wfp_instrument_recovered  2017-06-28      1
# 1012  ctdpf_ckl_wfp_instrument_recovered  2017-07-03      1
# 1015  ctdpf_ckl_wfp_instrument_recovered  2017-07-08      1
# 1016  ctdpf_ckl_wfp_instrument_recovered  2017-07-08      1
# 1017  ctdpf_ckl_wfp_instrument_recovered  2017-07-10      1
# 1019  ctdpf_ckl_wfp_instrument_recovered  2017-07-10      1
#
# [470 rows x 6 columns]

# %%
len(urls_test)
# Out:
# 1021

# %%
len(ooi_data)
# Out:
# 1021

# %%
trial = ooi_data[ooi_data.duplicated(keep=False)]

# %%
ooi_data['url']
# Out:
# 651    https://ooinet.oceanobservatories.org/api/m2m/...
# 653    https://ooinet.oceanobservatories.org/api/m2m/...
# 654    https://ooinet.oceanobservatories.org/api/m2m/...
# 658    https://ooinet.oceanobservatories.org/api/m2m/...
# 659    https://ooinet.oceanobservatories.org/api/m2m/...
# 665    https://ooinet.oceanobservatories.org/api/m2m/...
# Name: url, dtype: object

# %%
trial['url']
# Out:
# 651    https://ooinet.oceanobservatories.org/api/m2m/...
# 653    https://ooinet.oceanobservatories.org/api/m2m/...
# 654    https://ooinet.oceanobservatories.org/api/m2m/...
# 658    https://ooinet.oceanobservatories.org/api/m2m/...
# 659    https://ooinet.oceanobservatories.org/api/m2m/...
# 665    https://ooinet.oceanobservatories.org/api/m2m/...
# Name: url, dtype: object

# %%
request_url = 'https://ooinet.oceanobservatories.org/api/m2m/12576/sensor/inv/'+ \
                'GI02HYPM/WFP02/04-CTDPFL000/recovered_wfp/ctdpf_ckl_wfp_instrument_recovered?'+ \
                'beginDT=2014-09-13T00:00:00.000Z&'+\
                'endDT=2014-09-14T00:00:00.000Z'+\
                '&limit=1000'     
        
r = requests.get(request_url, auth=(username, token))

# %%
data = r.json()

# %%
for i in range(len(data)):
    timestamp = data[i]['time']
    timestamp = datetime.datetime.utcfromtimestamp(timestamp - ntp_delta).replace(microsecond=0)
#     timestamp = timestamp.date()
    print(timestamp)
# Out:
# 2014-09-12 07:39:27
# 2014-09-13 01:00:02
# 2014-09-13 01:00:37
# 2014-09-13 01:02:03
# 2014-09-13 01:03:29
# 2014-09-13 01:04:56
# 2014-09-13 01:06:22
# 2014-09-13 01:07:48
