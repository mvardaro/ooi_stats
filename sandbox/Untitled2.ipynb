# %%
import pandas as pd

# %%
df = '/Users/knuth/Documents/ooi/repos/github/ooi_stats/cabled.csv'

# %%
df = pd.read_csv(df)

# %%
del df['value']

# %%
df
# Out:
#                              refdes  deployment    method              stream  \
# 0       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 1       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 2       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 3       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 4       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 5       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 6       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 7       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 8       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 9       CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# 10      CE02SHBP-LJ01D-05-ADCPTB104         1.0  streamed  adcp_velocity_beam
# ...

# %%
test = df.duplicated()

# %%
type(test)
# Out:
# pandas.core.series.Series

# %%
for i in test:
#     print(i)
    if i == True:
        print(i)
    break
